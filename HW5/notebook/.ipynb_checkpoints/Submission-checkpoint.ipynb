# %%
import numpy as np
import h5py

# %%
filename = '../submission/v_seq_test_hmm'
with h5py.File(filename, "r") as f:
    # Model
    v_seq = np.array(f.get('v_seq_test'), dtype=int)
    v_seq_dev = np.array(f.get('v_seq_dev'), dtype=int)

# %%
filename = '../data/words_feature.hdf5'
with h5py.File(filename, "r") as f:
    # Model
    input_matrix_test = np.array(f.get('input_matrix_test'), dtype=int)
    input_matrix_dev = np.array(f.get('input_matrix_dev'), dtype=int)

# %%
tag2index = {}
with open('../data/tags.txt', 'r') as f:
    for line in f:
        line_split = line[:-1].split(' ')
        tag2index[line_split[0]] = int(line_split[1])

# Adding tags for end/start of sentence
print(tag2index)

# removing I and B from the tags
index2tag = {v:k for k,v in tag2index.iteritems()}
print(index2tag)
# Out:
# {'I-LOC': 3, 'I-PER': 2, 'O': 1, 'I-MISC': 5, 'B-MISC': 6, 'I-ORG': 4, 'B-LOC': 7}
# {1: 'O', 2: 'I-PER', 3: 'I-LOC', 4: 'I-ORG', 5: 'I-MISC', 6: 'B-MISC', 7: 'B-LOC'}

# %%
# Formating the output
def get_kaggle_output(pred_seq, input_matrix, index2tag):
    # #### First loop: build the list of results by line
    kaggle_output = []
    current_line = []
    for r_input, r_pred in zip(input_matrix, pred_seq):
        # Start of a new line
        if (r_input[1] == 1):
            kaggle_output.append(current_line)
            current_line = []
        else:
            if (r_pred > 1) and (r_pred < 8):
                current_line.append((r_input[1] - 1, r_pred))
    kaggle_output.append(current_line)
    # Remove first element
    kaggle_output = kaggle_output[1:]
    
    # #### Second loop: Format the result of each line

    kaggle_output_new = []
    for i, k in enumerate(kaggle_output):
        if len(k):
            current_seq = ''
            seq = ''
            prev_tag = ''
            prev_ind = -1
            for u in k:
                ind, tag_ind = u
                tag = index2tag[tag_ind][2:]
                # Growing the current tag sequence
                if tag == prev_tag and ind == prev_ind+1:
                    seq = seq+'-'+str(ind)
                # New tag
                else:
                    if len(seq):
                        current_seq += seq+' '
                    seq = tag+'-'+str(ind)
                    prev_tag = tag
                prev_ind = ind
            # adding remaining element
            current_seq += seq
            kaggle_output_new.append((i+1, current_seq))
        else:
            kaggle_output_new.append((i+1, ''))
    
    # Output: list of tuple (line_index, line_output)
    return kaggle_output_new

# %%
test = get_kaggle_output(v_seq, input_matrix_test, index2tag)

# %%
# Write to file
with open('../submission/v_seq_test_hmm.txt', 'w') as f:
    f.write('ID,Labels\n')
    for line in test:
        f.write(str(line[0]) + ',' + line[1] +'\n')

# %%
test
# Out:
# [(1, ''),
#  (2, 'LOC-1'),
#  (3, ''),
#  (4, ''),
#  (5, ''),
#  (6, ''),
#  (7, ''),
#  (8, ''),
#  (9, ''),
#  (10, 'ORG-5'),
#  (11, 'LOC-6'),
#  (12, 'LOC-1'),
#  (13, 'LOC-4'),
#  (14, ''),
#  (15, ''),
#  (16, ''),
#  (17, ''),
#  (18, ''),
#  (19, ''),
#  (20, 'LOC-1'),
#  (21, 'LOC-1'),
#  (22, 'LOC-1'),
#  (23, ''),
#  (24, 'LOC-1'),
#  (25, ''),
#  (26, 'PER-1-2'),
#  (27, 'LOC-1'),
#  (28, 'ORG-1 PER-3-4'),
#  (29, ''),
#  (30, 'LOC-39'),
#  (31, ''),
#  (32, 'LOC-1'),
#  (33, 'PER-1 LOC-10'),
#  (34, 'ORG-1-2'),
#  (35, 'LOC-1'),
#  (36, 'LOC-9'),
#  (37, 'ORG-8-9-10 LOC-19 LOC-30 PER-35-36'),
#  (38, ''),
#  (39, ''),
#  (40, 'LOC-18 LOC-40 ORG-43-44-45'),
#  (41, ''),
#  (42, ''),
#  (43, ''),
#  (44, 'LOC-1'),
#  (45, ''),
#  (46, 'ORG-1-2 LOC-4'),
#  (47, 'PER-7-8-9'),
#  (48, ''),
#  (49, ''),
#  (50, ''),
#  (51, ''),
#  (52, 'PER-1-2-3-4'),
#  (53, ''),
#  (54, 'LOC-35'),
#  (55, 'PER-6-7'),
#  (56, ''),
#  (57, 'LOC-3'),
#  (58, 'MISC-3-4-5-6'),
#  (59, ''),
#  (60, 'LOC-3 MISC-7'),
#  (61, 'LOC-3'),
#  (62, 'MISC-3'),
#  (63, 'LOC-1'),
#  (64, ''),
#  (65, ''),
#  (66, ''),
#  (67, 'LOC-2 LOC-4'),
#  (68, ''),
#  (69, 'LOC-6'),
#  (70, 'LOC-7 MISC-38'),
#  (71, 'LOC-3'),
#  (72, ''),
#  (73, 'LOC-2 LOC-4 MISC-17'),
#  (74, ''),
#  (75, ''),
#  (76, 'MISC-3-4'),
#  (77, 'LOC-1 LOC-3'),
#  (78, 'MISC-9-10 MISC-16'),
#  (79, 'PER-1-2-3 LOC-5 PER-12-13-14 LOC-16'),
#  (80, 'PER-1-2-3 LOC-5'),
#  (81, 'PER-1-2-3-4 LOC-6'),
#  (82, 'PER-1-2-3'),
#  (83, 'PER-1-2-3'),
#  (84, 'ORG-1-2-3 LOC-5 LOC-15'),
#  (85, 'PER-1-2-3 PER-9-10 LOC-19 PER-26-27 LOC-36 LOC-46'),
#  (86, 'LOC-19 PER-26-27 LOC-36'),
#  (87, 'PER-1-2-3 PER-9-10 LOC-19'),
#  (88, 'LOC-3'),
#  (89, ''),
#  (90, 'LOC-1 MISC-16'),
#  (91, ''),
#  (92, 'LOC-1-2'),
#  (93, 'LOC-1'),
#  (94, ''),
#  (95, 'LOC-3 LOC-5'),
#  (96, 'LOC-3'),
#  (97, 'LOC-1 LOC-3'),
#  (98, 'LOC-3 PER-8-9-10 LOC-13 PER-16-17-18-19-20-21-22'),
#  (99, 'LOC-5'),
#  (100, 'LOC-3'),
#  (101, ''),
#  (102, ''),
#  (103, ''),
#  (104, 'LOC-5'),
#  (105, 'LOC-5'),
#  (106, 'LOC-5'),
#  (107, 'LOC-5'),
#  (108, 'LOC-5'),
#  (109, 'LOC-5'),
#  (110, 'LOC-5'),
#  (111, 'LOC-5'),
#  (112, 'PER-2-3 LOC-5'),
#  (113, 'LOC-5'),
#  (114, ''),
#  (115, 'LOC-5'),
#  (116, 'LOC-5'),
#  (117, ''),
#  (118, 'LOC-5'),
#  (119, 'LOC-5'),
#  (120, ''),
#  (121, ''),
#  (122, 'LOC-6'),
#  (123, ''),
#  (124, ''),
#  (125, 'LOC-3 LOC-5'),
#  (126, 'LOC-3'),
#  (127, 'LOC-9 LOC-11'),
#  (128, 'LOC-1'),
#  (129, 'PER-1-2-3-4-5-6-7-8'),
#  (130, 'PER-1-2-3-4-5'),
#  (131, 'PER-1-2-3-4-5-6'),
#  (132, 'PER-1-2'),
#  (133, 'PER-1-2'),
#  (134, 'PER-1-2'),
#  (135, 'PER-1-2'),
#  (136, 'PER-1-2'),
#  (137, 'PER-1-2-3-4-5'),
#  (138, 'PER-1-2'),
#  (139, ''),
#  (140, ''),
#  (141, 'ORG-5-6-7-8-9-10'),
#  (142, 'PER-5-6'),
#  (143, 'PER-3-4-5 PER-7-8-9'),
#  (144, 'PER-4-5-6 PER-8-9'),
#  (145, 'PER-3-4-5'),
#  (146, 'LOC-1'),
#  (147, 'PER-1-2-3-4'),
#  (148, 'PER-1-2-3-4'),
#  (149, 'PER-1-2'),
#  (150, 'PER-1-2'),
#  (151, 'PER-1-2-3'),
#  (152, 'PER-1-2-3-4'),
#  (153, 'PER-1-2-3-4'),
#  (154, 'PER-1-2'),
#  (155, 'PER-1-2'),
#  (156, 'PER-1-2'),
#  (157, ''),
#  (158, ''),
#  (159, ''),
#  (160, 'ORG-9-10-11'),
#  (161, ''),
#  (162, ''),
#  (163, ''),
#  (164, ''),
#  (165, 'ORG-1 LOC-3'),
#  (166, ''),
#  (167, ''),
#  (168, ''),
#  (169, ''),
#  (170, 'LOC-5'),
#  (171, 'LOC-5'),
#  (172, 'LOC-5'),
#  (173, 'LOC-5'),
#  (174, 'LOC-5'),
#  (175, 'LOC-5'),
#  (176, 'LOC-5'),
#  (177, ''),
#  (178, 'LOC-5'),
#  (179, ''),
#  (180, 'LOC-1 LOC-21'),
#  (181, 'LOC-1 LOC-17'),
#  (182, 'LOC-1'),
#  (183, ''),
#  (184, 'LOC-5'),
#  (185, 'LOC-5'),
#  (186, 'LOC-5'),
#  (187, 'LOC-5'),
#  (188, 'LOC-5'),
#  (189, 'LOC-5'),
#  (190, 'LOC-5'),
#  (191, 'LOC-5'),
#  (192, ''),
#  (193, ''),
#  (194, 'LOC-5'),
#  (195, 'LOC-5'),
#  (196, ''),
#  (197, ''),
#  (198, 'LOC-1 LOC-17'),
#  (199, ''),
#  (200, ''),
#  (201, 'LOC-4'),
#  (202, 'PER-1-2 LOC-4 LOC-10'),
#  (203, 'PER-1-2 LOC-4 LOC-10'),
#  (204, 'LOC-4 LOC-10-11'),
#  (205, ''),
#  (206, ''),
#  (207, 'LOC-4'),
#  (208, ''),
#  (209, 'PER-1-2 LOC-4'),
#  (210, 'LOC-2'),
#  (211, 'LOC-4'),
#  (212, 'LOC-3'),
#  (213, 'LOC-4'),
#  (214, ''),
#  (215, 'LOC-3 LOC-8'),
#  (216, 'LOC-3'),
#  (217, 'LOC-1 LOC-7'),
#  (218, 'ORG-1-2-3-4 LOC-8 PER-18-19-20-21'),
#  (219, 'LOC-1 LOC-8'),
#  (220, ''),
#  (221, 'LOC-1 PER-27-28'),
#  (222,
#   'LOC-1 PER-3-4 PER-6-7 PER-9-10 PER-12-13 PER-17-18 PER-23-24 PER-26-27 PER-29-30 PER-32-33'),
#  (223, ''),
#  (224, ''),
#  (225, 'PER-1-2 ORG-14-15 ORG-18-19-20'),
#  (226, ''),
#  (227, ''),
#  (228, ''),
#  (229, ''),
#  (230, ''),
#  (231, ''),
#  (232, ''),
#  (233, ''),
#  (234, 'PER-1-2 MISC-25-26'),
#  (235, 'PER-1-2-3'),
#  (236, 'PER-1-2'),
#  (237, 'ORG-1 ORG-6-7 MISC-10-11'),
#  (238, 'ORG-1'),
#  (239, 'ORG-26-27'),
#  (240, 'LOC-1-2'),
#  (241, ''),
#  (242, ''),
#  (243, ''),
#  (244, 'PER-1-2-3'),
#  (245, 'ORG-21-22 ORG-25-26'),
#  (246, ''),
#  (247, 'LOC-1'),
#  (248, 'PER-1-2'),
#  (249, 'ORG-7-8 MISC-11-12-13-14'),
#  (250, 'PER-20-21 ORG-33-34-35-36'),
#  (251, 'PER-1'),
#  (252, ''),
#  (253, 'LOC-11'),
#  (254, 'ORG-31-32-33-34'),
#  (255, ''),
#  (256, ''),
#  (257, ''),
#  (258, 'LOC-4'),
#  (259, 'PER-4-5-6-7'),
#  (260, ''),
#  (261, ''),
#  (262, 'LOC-1'),
#  (263, ''),
#  (264, 'ORG-1'),
#  (265, 'PER-1-2'),
#  (266, 'PER-1-2'),
#  (267, ''),
#  (268, ''),
#  (269, 'LOC-1'),
#  (270, 'MISC-31-32'),
#  (271, ''),
#  (272, ''),
#  (273, ''),
#  (274, 'PER-1-2-3-4 MISC-19 MISC-27'),
#  (275, ''),
#  (276, ''),
#  (277, 'MISC-7'),
#  (278, 'LOC-1'),
#  (279, ''),
#  (280, 'ORG-1 MISC-5-6'),
#  (281, 'MISC-3'),
#  (282, 'PER-2-3-4'),
#  (283, ''),
#  (284, 'LOC-5'),
#  (285, ''),
#  (286, 'LOC-5'),
#  (287, ''),
#  (288, ''),
#  (289, 'PER-2-3 LOC-5'),
#  (290, 'PER-2-3'),
#  (291, 'PER-1-2-3'),
#  (292, 'PER-1-2-3'),
#  (293, 'PER-1-2-3'),
#  (294, 'PER-1-2-3 LOC-5'),
#  (295, 'PER-1-2-3 LOC-5'),
#  (296, 'PER-1-2-3 LOC-5-6'),
#  (297, 'PER-1-2-3-4 LOC-6'),
#  (298, 'PER-1-2-3'),
#  (299, 'PER-1-2-3-4 LOC-6'),
#  (300, 'PER-1-2-3'),
#  (301, 'PER-1-2-3'),
#  (302, 'ORG-1-2'),
#  (303, 'LOC-1'),
#  (304, ''),
#  (305, 'ORG-1-2-3'),
#  (306, 'MISC-1-2-3'),
#  (307, ''),
#  (308, 'LOC-1'),
#  (309, 'LOC-1'),
#  (310, ''),
#  (311, ''),
#  (312, ''),
#  (313, ''),
#  (314, ''),
#  (315, ''),
#  (316, ''),
#  (317, ''),
#  (318, 'ORG-1-2-3'),
#  (319, ''),
#  (320, ''),
#  (321, ''),
#  (322, ''),
#  (323, ''),
#  (324, ''),
#  (325, 'LOC-1'),
#  (326, 'LOC-1 ORG-3-4-5 MISC-15'),
#  (327, 'PER-26-27'),
#  (328, ''),
#  (329, 'LOC-3 LOC-6'),
#  (330, ''),
#  (331, 'LOC-1 LOC-4 MISC-15'),
#  (332, ''),
#  (333, ''),
#  (334, 'ORG-1-2'),
#  (335, 'LOC-1'),
#  (336, 'PER-4-5'),
#  (337, 'LOC-41'),
#  (338, 'MISC-1 LOC-22'),
#  (339, ''),
#  (340, 'LOC-2'),
#  (341, 'ORG-22-23-24'),
#  (342, ''),
#  (343, 'LOC-1'),
#  (344, 'MISC-1-2'),
#  (345, ''),
#  (346, ''),
#  (347, ''),
#  (348, ''),
#  (349, ''),
#  (350, 'ORG-1-2'),
#  (351, 'ORG-1-2'),
#  (352, ''),
#  (353, ''),
#  (354, ''),
#  (355, ''),
#  (356, ''),
#  (357, ''),
#  (358, ''),
#  (359, ''),
#  (360, ''),
#  (361, ''),
#  (362, ''),
#  (363, ''),
#  (364, ''),
#  (365, ''),
#  (366, ''),
#  (367, ''),
#  (368, ''),
#  (369, ''),
#  (370, ''),
#  (371, ''),
#  (372, ''),
#  (373, ''),
#  (374, ''),
#  (375, ''),
#  (376, ''),
#  (377, ''),
#  (378, ''),
#  (379, ''),
#  (380, 'MISC-3-4'),
#  (381, 'LOC-1'),
#  (382, 'MISC-1'),
#  (383, ''),
#  (384, ''),
#  (385, ''),
#  (386, ''),
#  (387, ''),
#  (388, ''),
#  (389, ''),
#  (390, ''),
#  (391, 'ORG-1-2-3'),
#  (392, ''),
#  (393, ''),
#  (394, ''),
#  (395, ''),
#  (396, ''),
#  (397, ''),
#  (398, ''),
#  (399, ''),
#  (400, ''),
#  (401, ''),
#  (402, 'LOC-1'),
#  (403, 'ORG-1'),
#  (404, 'LOC-1'),
#  (405, ''),
#  (406, 'ORG-1-2'),
#  (407, ''),
#  (408, ''),
#  (409, ''),
#  (410, ''),
#  (411, ''),
#  (412, ''),
#  (413, ''),
#  (414, ''),
#  (415, ''),
#  (416, ''),
#  (417, ''),
#  (418, 'LOC-1'),
#  (419, ''),
#  (420, ''),
#  (421, ''),
#  (422, ''),
#  (423, ''),
#  (424, ''),
#  (425, ''),
#  (426, ''),
#  (427, ''),
#  (428, ''),
#  (429, ''),
#  (430, ''),
#  (431, ''),
#  (432, ''),
#  (433, ''),
#  (434, ''),
#  (435, ''),
#  (436, ''),
#  (437, ''),
#  (438, ''),
#  (439, ''),
#  (440, ''),
#  (441, 'LOC-1'),
#  (442, ''),
#  (443, ''),
#  (444, ''),
#  (445, 'LOC-1'),
#  (446, 'LOC-1'),
#  (447, ''),
#  (448, ''),
#  (449, 'LOC-1-2'),
#  (450, ''),
#  (451, ''),
#  (452, ''),
#  (453, ''),
#  (454, ''),
#  (455, ''),
#  (456, ''),
#  (457, 'LOC-1'),
#  (458, ''),
#  (459, ''),
#  (460, ''),
#  (461, 'LOC-1'),
#  (462, ''),
#  (463, ''),
#  (464, ''),
#  (465, ''),
#  (466, 'ORG-3-4'),
#  (467, ''),
#  (468, 'ORG-8-9'),
#  (469, ''),
#  (470, ''),
#  (471, ''),
#  (472, ''),
#  (473, ''),
#  (474, ''),
#  (475, ''),
#  (476, ''),
#  (477, ''),
#  (478, ''),
#  (479, ''),
#  (480, ''),
#  (481, ''),
#  (482, 'MISC-3-4'),
#  (483, 'LOC-1'),
#  (484, ''),
#  (485, ''),
#  (486, ''),
#  (487, ''),
#  (488, ''),
#  (489, ''),
#  (490, ''),
#  (491, ''),
#  (492, ''),
#  (493, ''),
#  (494, ''),
#  (495, ''),
#  (496, 'ORG-4-5-6'),
#  (497, ''),
#  (498, ''),
#  (499, ''),
#  (500, ''),
#  (501, ''),
#  (502, ''),
#  (503, ''),
#  (504, ''),
#  (505, ''),
#  (506, 'LOC-4'),
#  (507, ''),
#  (508, ''),
#  (509, ''),
#  (510, ''),
#  (511, 'LOC-1-2'),
#  (512, 'LOC-1'),
#  (513, ''),
#  (514, ''),
#  (515, ''),
#  (516, ''),
#  (517, ''),
#  (518, ''),
#  (519, ''),
#  (520, ''),
#  (521, 'MISC-3-4'),
#  (522, 'LOC-1'),
#  (523, 'MISC-7-8'),
#  (524, ''),
#  (525, 'PER-11-12-13 PER-15-16-17'),
#  (526, ''),
#  (527, ''),
#  (528, 'ORG-1-2'),
#  (529, ''),
#  (530, ''),
#  (531, 'ORG-1-2 PER-12-13-14-15-16-17-18'),
#  (532, ''),
#  (533, 'LOC-5'),
#  (534, 'ORG-1-2 PER-6-7-8 PER-10-11-12 PER-18-19 PER-22-23'),
#  (535, ''),
#  (536, 'PER-16-17-18-19-20'),
#  (537, ''),
#  (538, 'PER-20-21 PER-24-25-26'),
#  (539, 'PER-9-10'),
#  (540, ''),
#  (541, ''),
#  (542, ''),
#  (543, ''),
#  (544, ''),
#  (545, ''),
#  (546, 'PER-2-3 LOC-5'),
#  (547, ''),
#  (548, 'PER-2-3 LOC-5'),
#  (549, 'LOC-5'),
#  (550, 'LOC-5'),
#  (551, 'LOC-5'),
#  (552, 'PER-2-3 LOC-5'),
#  (553, 'LOC-6'),
#  (554, 'PER-2-3'),
#  (555, ''),
#  (556, 'PER-1-2-3-4'),
#  (557, 'LOC-3'),
#  (558, ''),
#  (559, 'LOC-1'),
#  (560, ''),
#  (561, 'LOC-1 PER-11-12'),
#  (562, 'PER-3-4-5-6'),
#  (563, ''),
#  (564, 'ORG-1-2'),
#  (565, ''),
#  (566, 'LOC-1'),
#  (567, 'LOC-1-2'),
#  (568, ''),
#  (569, 'MISC-34-35'),
#  (570, 'ORG-1-2-3-4-5-6 PER-22-23-24'),
#  (571, 'PER-1-2-3'),
#  (572, ''),
#  (573, 'PER-12-13'),
#  (574, 'PER-1-2-3-4-5'),
#  (575, ''),
#  (576, 'PER-32-33-34-35-36-37'),
#  (577, ''),
#  (578, ''),
#  (579, ''),
#  (580, ''),
#  (581, ''),
#  (582, 'LOC-1-2 PER-50-51 PER-61-62'),
#  (583, 'LOC-1-2 PER-57-58 PER-73-74'),
#  (584, 'ORG-1-2 LOC-4-5'),
#  (585, 'LOC-1'),
#  (586, 'LOC-1-2'),
#  (587, ''),
#  (588, 'LOC-1-2'),
#  (589, ''),
#  (590, ''),
#  (591, 'LOC-1-2'),
#  (592, ''),
#  (593, ''),
#  (594, 'LOC-1-2'),
#  (595, ''),
#  (596, ''),
#  (597, ''),
#  (598, ''),
#  (599, ''),
#  (600, 'MISC-8-9-10'),
#  (601, ''),
#  (602, 'MISC-8-9-10'),
#  (603, ''),
#  (604, ''),
#  (605, 'LOC-1'),
#  (606, ''),
#  (607, ''),
#  (608, ''),
#  (609, ''),
#  (610, ''),
#  (611, ''),
#  (612, ''),
#  (613, ''),
#  (614, ''),
#  (615, ''),
#  (616, ''),
#  (617, 'ORG-1-2'),
#  (618, ''),
#  (619, ''),
#  (620, ''),
#  (621, ''),
#  (622, ''),
#  (623, ''),
#  (624, ''),
#  (625, ''),
#  (626, ''),
#  (627, ''),
#  (628, ''),
#  (629, ''),
#  (630, ''),
#  (631, ''),
#  (632, ''),
#  (633, ''),
#  (634, ''),
#  (635, ''),
#  (636, ''),
#  (637, ''),
#  (638, ''),
#  (639, ''),
#  (640, ''),
#  (641, ''),
#  (642, ''),
#  (643, ''),
#  (644, ''),
#  (645, ''),
#  (646, ''),
#  (647, ''),
#  (648, ''),
#  (649, ''),
#  (650, ''),
#  (651, 'LOC-1 PER-5-6 PER-20-21-22'),
#  (652, 'LOC-17'),
#  (653, ''),
#  (654, ''),
#  (655, 'LOC-1'),
#  (656, ''),
#  (657, 'LOC-1'),
#  (658, ''),
#  (659, ''),
#  (660, ''),
#  (661, 'LOC-3 LOC-8'),
#  (662, ''),
#  (663, 'LOC-3 LOC-9'),
#  (664, ''),
#  (665, 'LOC-1'),
#  (666, ''),
#  (667, ''),
#  (668, ''),
#  (669, 'LOC-3 LOC-8'),
#  (670, ''),
#  (671, 'LOC-3 LOC-9'),
#  (672, ''),
#  (673, ''),
#  (674, 'LOC-1 MISC-14'),
#  (675, ''),
#  (676, 'LOC-1'),
#  (677, ''),
#  (678, ''),
#  (679, ''),
#  (680, 'LOC-1 MISC-11'),
#  (681, ''),
#  (682, 'LOC-5'),
#  (683, 'LOC-1'),
#  (684, 'LOC-1 LOC-3 MISC-14'),
#  (685, ''),
#  (686, ''),
#  (687, ''),
#  (688, ''),
#  (689, 'LOC-1'),
#  (690, 'LOC-3 LOC-7'),
#  (691, 'LOC-3 MISC-7'),
#  (692, ''),
#  (693, 'LOC-1 MISC-11'),
#  (694, 'PER-8-9'),
#  (695, ''),
#  (696, ''),
#  (697, ''),
#  (698, 'LOC-1 MISC-14'),
#  (699, ''),
#  (700, ''),
#  (701, 'LOC-3'),
#  (702, ''),
#  (703, 'LOC-1 MISC-11'),
#  (704, ''),
#  (705, ''),
#  (706, ''),
#  (707, 'LOC-1-2'),
#  (708, 'PER-1-2-3-4-5-6-7 LOC-21-22'),
#  (709, ''),
#  (710, ''),
#  (711, ''),
#  (712, ''),
#  (713, 'PER-1'),
#  (714, 'MISC-2'),
#  (715, ''),
#  (716, ''),
#  (717, ''),
#  (718, ''),
#  (719, ''),
#  (720, ''),
#  (721, ''),
#  (722, ''),
#  (723, 'LOC-7-8 MISC-14-15-16'),
#  (724, ''),
#  (725, 'MISC-11-12'),
#  (726, ''),
#  (727, ''),
#  (728, ''),
#  (729, 'LOC-3-4'),
#  (730, 'LOC-1-2'),
#  (731, 'LOC-5-6 LOC-22 PER-25-26 LOC-28 LOC-39'),
#  (732, ''),
#  (733, 'ORG-1'),
#  (734, 'LOC-4'),
#  (735, ''),
#  (736, ''),
#  (737, ''),
#  (738, ''),
#  (739, ''),
#  (740, 'LOC-15'),
#  (741, ''),
#  (742, ''),
#  (743, ''),
#  (744, ''),
#  (745, ''),
#  (746, ''),
#  (747, ''),
#  (748, ''),
#  (749, ''),
#  (750, ''),
#  (751, ''),
#  (752, ''),
#  (753, ''),
#  (754, ''),
#  (755, ''),
#  (756, 'PER-1-2'),
#  (757, 'PER-1-2'),
#  (758, 'PER-1-2'),
#  (759, ''),
#  (760, 'LOC-3 LOC-5'),
#  (761, 'PER-1'),
#  (762, 'LOC-1-2'),
#  (763, 'LOC-10 LOC-13-14 LOC-38'),
#  (764, 'LOC-1 LOC-4 LOC-8 LOC-13'),
#  (765, 'LOC-9 LOC-12-13 LOC-16 LOC-18'),
#  (766, ''),
#  (767, 'LOC-29'),
#  (768, 'LOC-31'),
#  (769, ''),
#  (770, 'LOC-2-3 LOC-5 LOC-19'),
#  (771, 'LOC-4 LOC-18'),
#  (772, ''),
#  (773, ''),
#  (774, 'PER-14-15-16'),
#  (775, 'LOC-8'),
#  (776, ''),
#  (777, 'PER-15-16-17'),
#  (778, 'LOC-18 PER-23-24-25 PER-27-28'),
#  (779, ''),
#  (780, 'LOC-8'),
#  (781, 'LOC-1-2'),
#  (782, 'LOC-4'),
#  (783, 'PER-9-10 LOC-12 LOC-27 LOC-33 LOC-40 LOC-46-47'),
#  (784, 'PER-9-10 LOC-12'),
#  (785, ''),
#  (786, 'LOC-1-2'),
#  (787, 'LOC-17'),
#  (788, ''),
#  (789, 'LOC-1-2'),
#  (790, 'LOC-1-2 LOC-4'),
#  (791, 'LOC-1'),
#  (792, 'LOC-1'),
#  (793, ''),
#  (794, ''),
#  (795, 'LOC-1'),
#  (796, 'LOC-1'),
#  (797, 'LOC-1'),
#  (798, 'LOC-1'),
#  (799, 'LOC-3'),
#  (800, 'ORG-1-2'),
#  (801, 'LOC-2-3'),
#  (802, ''),
#  (803, 'LOC-1'),
#  (804, 'PER-1-2'),
#  (805, ''),
#  (806, ''),
#  (807, 'LOC-1-2'),
#  (808, ''),
#  (809, ''),
#  (810, ''),
#  (811, 'MISC-1'),
#  (812, ''),
#  (813, ''),
#  (814, 'LOC-1-2'),
#  (815, 'LOC-1'),
#  (816, 'LOC-1'),
#  (817, 'ORG-1'),
#  (818, 'ORG-1-2-3-4'),
#  (819, ''),
#  (820, 'ORG-1'),
#  (821, 'LOC-1'),
#  (822, 'LOC-1'),
#  (823, 'ORG-1'),
#  (824, 'LOC-1'),
#  (825, ''),
#  (826, 'ORG-1'),
#  (827, 'ORG-1'),
#  (828, 'ORG-1'),
#  (829, 'LOC-1'),
#  (830, ''),
#  (831, 'LOC-1'),
#  (832, 'LOC-1'),
#  (833, 'LOC-1'),
#  (834, 'LOC-1'),
#  (835, 'ORG-1'),
#  (836, 'LOC-1'),
#  (837, 'LOC-1-2'),
#  (838, ''),
#  (839, ''),
#  (840, ''),
#  (841, 'LOC-1'),
#  (842, 'ORG-1'),
#  (843, 'LOC-1'),
#  (844, 'LOC-1-2'),
#  (845, 'ORG-1'),
#  (846, ''),
#  (847, 'LOC-1'),
#  (848, 'ORG-1-2'),
#  (849, 'LOC-1'),
#  (850, 'ORG-1'),
#  (851, 'ORG-1-2-3-4'),
#  (852, ''),
#  (853, 'ORG-1-2'),
#  (854, 'ORG-1-2'),
#  (855, 'LOC-1'),
#  (856, 'ORG-1-2'),
#  (857, ''),
#  (858, 'LOC-1'),
#  (859, 'LOC-1'),
#  (860, 'ORG-1-2'),
#  (861, 'LOC-1'),
#  (862, 'ORG-1-2'),
#  (863, 'ORG-1-2'),
#  (864, 'LOC-1 ORG-3-4'),
#  (865, ''),
#  (866, 'LOC-1-2'),
#  (867, ''),
#  (868, ''),
#  (869, 'MISC-1'),
#  (870, 'ORG-1'),
#  (871, 'ORG-1-2-3'),
#  (872, 'ORG-1'),
#  (873, 'ORG-1'),
#  (874, 'LOC-1-2'),
#  (875, 'ORG-1-2-3'),
#  (876, 'LOC-1'),
#  (877, ''),
#  (878, 'LOC-1 LOC-3'),
#  (879, 'LOC-1 LOC-3'),
#  (880, 'LOC-1'),
#  (881, 'ORG-1-2-3-4'),
#  (882, 'ORG-1-2-3-4'),
#  (883, 'LOC-1'),
#  (884, 'ORG-1-2 LOC-5'),
#  (885, 'ORG-1-2-3-4'),
#  (886, 'PER-3-4-5-6'),
#  (887, 'ORG-1'),
#  (888, 'ORG-26-27'),
#  (889, 'PER-5-6-7'),
#  (890, ''),
#  (891, ''),
#  (892, 'PER-6-7'),
#  (893, ''),
#  (894, ''),
#  (895, ''),
#  (896, ''),
#  (897, ''),
#  (898, ''),
#  (899, 'ORG-26-27-28'),
#  (900, 'ORG-1-2'),
#  (901, ''),
#  (902, 'PER-1-2'),
#  (903, ''),
#  (904, 'PER-1-2 LOC-8-9'),
#  (905, 'LOC-2'),
#  (906, 'LOC-23'),
#  (907, ''),
#  (908, ''),
#  (909, 'PER-1-2-3-4 LOC-8'),
#  (910, 'PER-1-2-3 LOC-9'),
#  (911, 'ORG-25-26-27-28'),
#  (912, ''),
#  (913, 'PER-7-8'),
#  (914, ''),
#  (915, 'PER-1-2'),
#  (916, 'ORG-1'),
#  (917, 'LOC-3 ORG-27-28-29'),
#  (918, ''),
#  (919, ''),
#  (920, ''),
#  (921, ''),
#  (922, 'ORG-2-3'),
#  (923, ''),
#  (924, 'ORG-1-2-3-4'),
#  (925, ''),
#  (926, 'PER-1-2'),
#  (927, ''),
#  (928, ''),
#  (929, ''),
#  (930, ''),
#  (931, 'PER-1'),
#  (932, 'LOC-1-2'),
#  (933, 'PER-9-10 LOC-19'),
#  (934, 'MISC-22'),
#  (935, ''),
#  (936, ''),
#  (937, ''),
#  (938, ''),
#  (939, ''),
#  (940, ''),
#  (941, 'PER-1'),
#  (942, 'PER-36-37'),
#  (943, ''),
#  (944, ''),
#  (945, 'PER-1'),
#  (946, 'PER-1'),
#  (947, ''),
#  (948, ''),
#  (949, 'PER-1'),
#  (950, 'PER-29-30'),
#  (951, ''),
#  (952, ''),
#  (953, ''),
#  (954, ''),
#  (955, ''),
#  (956, ''),
#  (957, 'LOC-1'),
#  (958, 'LOC-1'),
#  (959, 'LOC-5'),
#  (960, 'PER-1'),
#  (961, 'LOC-1'),
#  (962, 'LOC-1'),
#  (963, 'LOC-1'),
#  (964, 'LOC-1'),
#  (965, ''),
#  (966, 'ORG-1 PER-3-4 PER-18-19'),
#  (967, ''),
#  (968, 'PER-10-11'),
#  (969, ''),
#  (970, 'ORG-1-2'),
#  (971, ''),
#  (972, ''),
#  (973, ''),
#  (974, ''),
#  (975, ''),
#  (976, 'LOC-1 PER-3-4'),
#  (977, 'LOC-1 PER-9-10 PER-18-19 PER-21-22 PER-38-39'),
#  (978, 'PER-3-4-5-6'),
#  (979, 'LOC-1'),
#  (980, 'PER-1-2-3-4-5'),
#  (981, 'LOC-3'),
#  (982, 'LOC-1'),
#  (983, 'PER-1-2-3-4-5 LOC-17'),
#  (984, 'LOC-7'),
#  (985, 'PER-16-17-18'),
#  (986, 'LOC-10'),
#  (987, 'LOC-7'),
#  (988, 'MISC-29'),
#  (989, 'PER-34-35'),
#  (990, 'LOC-8'),
#  (991, ''),
#  (992, 'LOC-1 PER-64-65-66'),
#  (993, 'LOC-1 MISC-36-37 PER-66-67-68'),
#  (994, 'LOC-3'),
#  (995, 'LOC-1'),
#  (996, 'LOC-1'),
#  (997, ''),
#  (998, ''),
#  (999, 'LOC-3 LOC-6'),
#  (1000, ''),
#  ...]
